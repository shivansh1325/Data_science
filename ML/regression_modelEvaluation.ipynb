# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import RandomizedSearchCV,train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
data= pd.read_csv("../ML/boston_house_prices.csv",header= 1)
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
from sklearn.datasets import load_b

# %%
x = data.drop(columns= ['MEDV'])
x.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT
# 0  396.90   4.98
# 1  396.90   9.14
# 2  392.83   4.03
# 3  394.63   2.94
# 4  396.90   5.33

# %%
y=data['MEDV']
y.head()
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: MEDV, dtype: float64

# %%
data.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.35,random_state= 46)

# %%
model = RandomForestRegressor()

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
model.predict(x_test)
# Out:
# array([18.597, 26.681, 14.984, 14.047, 22.076, 18.744, 25.884, 18.271,
#        15.751, 19.989, 27.783, 17.645, 22.213, 12.05 , 20.527, 28.389,
#        30.32 , 19.601, 19.974, 22.888, 16.682, 31.203, 19.055, 22.588,
#        21.199, 24.162, 44.708, 23.086, 19.393, 29.37 , 47.789, 33.99 ,
#        15.639,  7.97 , 43.011, 32.668, 19.539, 17.588, 21.217, 22.041,
#        29.537, 23.929, 26.5  , 10.753, 25.46 , 19.673, 20.075, 19.936,
#        16.194, 33.938, 19.834, 19.644, 23.369, 21.629, 23.823, 31.349,
#        34.695, 14.044, 16.388, 24.599, 34.042, 15.852, 15.818, 11.511,
#        40.032, 18.008, 21.991, 22.552, 26.753, 16.688, 32.377, 21.671,
#        15.162, 30.73 , 15.748, 18.221, 15.019, 18.176, 10.631, 20.02 ,
#        21.231, 12.805, 17.894, 14.845, 11.274, 14.672, 25.137, 11.763,
#        24.034, 21.49 , 16.246, 21.797, 15.386, 21.894, 20.366, 21.567,
#        26.606, 15.41 , 26.009, 14.571, 27.072, 13.55 , 46.274, 17.333,
# ...

# %%
# defining the parameter gride for 
param_distribution={
    "n_estimators":[int(x) for x in np.linspace(100,1000, num= 10)],
    "max_features":["auto","sqrt","log"],
    "max_depth":[int(x) for x in np.linspace(10,110,num=11)],
    "min_samples_split":[2,5,10],
    "min_samples_leaf":[1,2,4],
    "bootstrap":[True,False]
}

# %%
for x in np.linspace(1,100,num=9):
    print(x)
# Out:
# 1.0
# 13.375
# 25.75
# 38.125
# 50.5
# 62.875
# 75.25
# 87.625
# 100.0

# %%
#setting randomizedSearchcv 
random_searchcv= RandomizedSearchCV(
    estimator=model,
    param_distributions=param_distribution,
    n_iter=200,
    cv=5,
    verbose=2,
    random_state= 45,
    n_jobs=-1
)

# %%
random_searchcv.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# G:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 620 fits failed out of a total of 1000.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 255 fits failed with the following error:
# Traceback (most recent call last):
#   File "G:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "G:\anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "G:\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
# ...

# %%
#best hyperparameter
best_param = random_searchcv.best_estimator_
print(best_param)
y_pred = best_param.predict(x_test)
# Out:
# RandomForestRegressor(bootstrap=False, max_depth=110, max_features='sqrt',
#                       n_estimators=600)

# %%
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
r2_ = r2_score(y_test,y_pred)
mae = mean_absolute_error(y_test,y_pred)
print("root mean square error",rmse)
print("root mean square error",r2_)
print("root mean square error",mae)
# Out:
# root mean square error 2.9295520462677422
# root mean square error 0.8839865637893572
# root mean square error 2.1570496254681553

# %% [markdown]
# # error -------> Training ======> Bias
# # error -------> testing ======> Variance
# # underFitting
# # high bias and high variance
# # overfitting
# # low bias and high variance
