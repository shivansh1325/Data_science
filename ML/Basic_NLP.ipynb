# %%
# !pip install nltk
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
import nltk

# %%
rompom = """ In the quiet hush of twilight’s embrace,
Your gaze finds mine in a timeless dance,
A spark ignites in the softest place,
Where love and longing intertwine by chance.

Fingers trace paths like rivers unknown,
Over hills and valleys, soft and warm,
Each touch a promise, each breath a moan,
As we surrender to passion's storm.

The night unfolds, a velvet sheet,
Wrapped in the heat of whispered desire,
Your lips, like wine, taste bittersweet,
Setting our hearts and bodies afire.

Beneath the stars, we lose our way,
In the rhythm of a secret song,
Where every glance and word we say,
Makes the night both tender and strong.

In this dance of shadows, sweet and slow,
We find the fire that lovers seek,
As the moon dips low and embers glow,
Our love speaks the words we dare not speak. """

# %%
from nltk.tokenize import sent_tokenize,word_tokenize

# %%
import nltk
nltk.download('punkt')

worrd_tok= sent_tokenize(rompom)
worrd_tok
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\shiva\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [' In the quiet hush of twilight’s embrace,\nYour gaze finds mine in a timeless dance,\nA spark ignites in the softest place,\nWhere love and longing intertwine by chance.',
#  "Fingers trace paths like rivers unknown,\nOver hills and valleys, soft and warm,\nEach touch a promise, each breath a moan,\nAs we surrender to passion's storm.",
#  'The night unfolds, a velvet sheet,\nWrapped in the heat of whispered desire,\nYour lips, like wine, taste bittersweet,\nSetting our hearts and bodies afire.',
#  'Beneath the stars, we lose our way,\nIn the rhythm of a secret song,\nWhere every glance and word we say,\nMakes the night both tender and strong.',
#  'In this dance of shadows, sweet and slow,\nWe find the fire that lovers seek,\nAs the moon dips low and embers glow,\nOur love speaks the words we dare not speak.']

# %%
word=word_tokenize(rompom)

# %%
word
# Out:
# ['In',
#  'the',
#  'quiet',
#  'hush',
#  'of',
#  'twilight',
#  '’',
#  's',
#  'embrace',
#  ',',
#  'Your',
#  'gaze',
#  'finds',
#  'mine',
#  'in',
#  'a',
#  'timeless',
#  'dance',
#  ',',
#  'A',
#  'spark',
#  'ignites',
#  'in',
#  'the',
#  'softest',
#  'place',
#  ',',
#  'Where',
#  'love',
#  'and',
#  'longing',
#  'intertwine',
#  'by',
#  'chance',
#  '.',
#  'Fingers',
#  'trace',
#  'paths',
#  'like',
#  'rivers',
#  'unknown',
#  ',',
#  'Over',
#  'hills',
#  'and',
#  'valleys',
#  ',',
#  'soft',
#  'and',
#  'warm',
#  ',',
#  'Each',
#  'touch',
#  'a',
#  'promise',
#  ',',
#  'each',
#  'breath',
#  'a',
#  'moan',
#  ',',
#  'As',
#  'we',
#  'surrender',
#  'to',
#  'passion',
#  "'s",
#  'storm',
#  '.',
#  'The',
#  'night',
#  'unfolds',
#  ',',
#  'a',
#  'velvet',
#  'sheet',
#  ',',
#  'Wrapped',
#  'in',
#  'the',
#  'heat',
#  'of',
#  'whispered',
#  'desire',
#  ',',
#  'Your',
#  'lips',
#  ',',
#  'like',
#  'wine',
#  ',',
#  'taste',
# ...

# %% [markdown]
# # Cleaning

# %%
from string import punctuation

# %%
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
text ="hello@hi,$%{{[))!heksdbnd"
worrd_tok=word_tokenize(rompom)
worrd_tok
# Out:
# ['In',
#  'the',
#  'quiet',
#  'hush',
#  'of',
#  'twilight',
#  '’',
#  's',
#  'embrace',
#  ',',
#  'Your',
#  'gaze',
#  'finds',
#  'mine',
#  'in',
#  'a',
#  'timeless',
#  'dance',
#  ',',
#  'A',
#  'spark',
#  'ignites',
#  'in',
#  'the',
#  'softest',
#  'place',
#  ',',
#  'Where',
#  'love',
#  'and',
#  'longing',
#  'intertwine',
#  'by',
#  'chance',
#  '.',
#  'Fingers',
#  'trace',
#  'paths',
#  'like',
#  'rivers',
#  'unknown',
#  ',',
#  'Over',
#  'hills',
#  'and',
#  'valleys',
#  ',',
#  'soft',
#  'and',
#  'warm',
#  ',',
#  'Each',
#  'touch',
#  'a',
#  'promise',
#  ',',
#  'each',
#  'breath',
#  'a',
#  'moan',
#  ',',
#  'As',
#  'we',
#  'surrender',
#  'to',
#  'passion',
#  "'s",
#  'storm',
#  '.',
#  'The',
#  'night',
#  'unfolds',
#  ',',
#  'a',
#  'velvet',
#  'sheet',
#  ',',
#  'Wrapped',
#  'in',
#  'the',
#  'heat',
#  'of',
#  'whispered',
#  'desire',
#  ',',
#  'Your',
#  'lips',
#  ',',
#  'like',
#  'wine',
#  ',',
#  'taste',
# ...

# %%
filtered = [ word for word in worrd_tok if word not in punctuation]

# %%
filtered
# Out:
# ['In',
#  'the',
#  'quiet',
#  'hush',
#  'of',
#  'twilight',
#  '’',
#  's',
#  'embrace',
#  'Your',
#  'gaze',
#  'finds',
#  'mine',
#  'in',
#  'a',
#  'timeless',
#  'dance',
#  'A',
#  'spark',
#  'ignites',
#  'in',
#  'the',
#  'softest',
#  'place',
#  'Where',
#  'love',
#  'and',
#  'longing',
#  'intertwine',
#  'by',
#  'chance',
#  'Fingers',
#  'trace',
#  'paths',
#  'like',
#  'rivers',
#  'unknown',
#  'Over',
#  'hills',
#  'and',
#  'valleys',
#  'soft',
#  'and',
#  'warm',
#  'Each',
#  'touch',
#  'a',
#  'promise',
#  'each',
#  'breath',
#  'a',
#  'moan',
#  'As',
#  'we',
#  'surrender',
#  'to',
#  'passion',
#  "'s",
#  'storm',
#  'The',
#  'night',
#  'unfolds',
#  'a',
#  'velvet',
#  'sheet',
#  'Wrapped',
#  'in',
#  'the',
#  'heat',
#  'of',
#  'whispered',
#  'desire',
#  'Your',
#  'lips',
#  'like',
#  'wine',
#  'taste',
#  'bittersweet',
#  'Setting',
#  'our',
#  'hearts',
#  'and',
#  'bodies',
#  'afire',
#  'Beneath',
#  'the',
# ...
